# %% [markdown]
# <a href="https://colab.research.google.com/github/sarthakshukla74/BLACK-FRIDAY-SALE-EDA-/blob/main/BLACK_FRIDAY_SALE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e5587679-37af-4646-8620-6b887379c6d4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e5587679-37af-4646-8620-6b887379c6d4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('BlackFriday.csv')

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df.shape
# Out:
# (537577, 12)

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
del df['Product_Category_2']
del df['Product_Category_3']

# %%
df['User_ID'].unique()
# Out:
# array([1000001, 1000002, 1000003, ..., 1004113, 1005391, 1001529])

# %%
df['User_ID'].nunique()
# Out:
# 5891

# %%
df['Product_ID'].nunique()
# Out:
# 3623

# %%
df['Gender'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df['Gender'].nunique()
# Out:
# 2

# %%
df['Occupation'].unique()
# Out:
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6])

# %%
df['Marital_Status'].unique()
# Out:
# array([0, 1])

# %%
df['Marital_Status'].nunique()
# Out:
# 2

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
df['Stay_In_Current_City_Years'].nunique()
# Out:
# 5

# %%
df['Purchase'].sum()/len(df['Purchase'])
# Out:
# np.float64(9333.859852635065)

# %%
for col in df.columns:

  print(col,df[col].unique())
# Out:
# User_ID [1000001 1000002 1000003 ... 1004113 1005391 1001529]
# Product_ID ['P00069042' 'P00248942' 'P00087842' ... 'P00038842' 'P00295642'
#  'P00091742']
# Gender ['F' 'M']
# Age ['0-17' '55+' '26-35' '46-50' '51-55' '36-45' '18-25']
# Occupation [10 16 15  7 20  9  1 12 17  0  3  4 11  8 19  2 18  5 14 13  6]
# City_Category ['A' 'C' 'B']
# Stay_In_Current_City_Years ['2' '4+' '3' '1' '0']
# Marital_Status [0 1]
# Product_Category_1 [ 3  1 12  8  5  4  2  6 14 11 13 15  7 16 18 10 17  9]
# Purchase [ 8370 15200  1422 ... 14539 11120 18426]

# %%
data=pd.DataFrame({'Ratio' : [len(df[df['Gender']=='M']),len(df[df['Gender']=='F'])]},index=['Male','Female'])

# %%
data
# Out:
#          Ratio
# Male    405380
# Female  132197

# %%
data.plot.pie(y='Ratio',figsize=(6,6),autopct="%.1f")
# Out:
# <Axes: ylabel='Ratio'>

# %%
df.groupby('Gender').size().plot(kind='pie',autopct='%0.1f',title='Gender Ratio',figsize=(6,6))
print(df.groupby('Gender').size())
# Out:
# Gender
# F    132197
# M    405380
# dtype: int64

# %% [markdown]
# **BAR PLOT FOR THE SAME**

# %%
df.groupby('Gender').size().plot(kind='bar',title='Gender',figsize=(6,6),color=['red','green'], rot=360)
# Out:
# <Axes: title={'center': 'Gender'}, xlabel='Gender'>

# %% [markdown]
# **TOTAL PURCHASE BY EACH GENDER**

# %%
df.groupby('Gender').sum()['Purchase'].plot(kind='pie',autopct='%0.1f',title='Gender Pruchase Ratio',figsize=(6,6))
# Out:
# <Axes: title={'center': 'Gender Pruchase Ratio'}, ylabel='Purchase'>

# %% [markdown]
# **AVERAGE PURCHASE FOR EACH GENDER**

# %%
df.groupby('Gender')['Purchase'].mean().plot(kind='pie',autopct='%0.1f',title='Average Purchase Ratio',figsize=(6,6))
# Out:
# <Axes: title={'center': 'Average Purchase Ratio'}, ylabel='Purchase'>

# %% [markdown]
# **AGE ANALYSIS**

# %%
df.groupby('Age').size().plot(kind='bar',figsize=(6,6),rot=360,title='Purchase Distribution By Age')
# Out:
# <Axes: title={'center': 'Purchase Distribution By Age'}, xlabel='Age'>

# %% [markdown]
# **NUMBER OF UNIQUE PRODUCTS BOUGHT BY DIFFERENT AGE GROUPS**

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
lst=[]
for i in df['Age'].unique():
  lst.append([i,df[df['Age']==i]['Product_ID'].nunique()])
data=pd.DataFrame(lst,columns=['Age','Product'])
data
# Out:
#      Age  Product
# 0   0-17     2300
# 1    55+     2573
# 2  26-35     3419
# 3  46-50     3099
# 4  51-55     2877
# 5  36-45     3318
# 6  18-25     3213

# %%
df[df['Age']==i]['Product_ID'].nunique()
# Out:
# 3213

# %%
data.plot(kind='bar',figsize=(6,6),rot=360,x='Age')
# Out:
# <Axes: xlabel='Age'>

# %% [markdown]
# **TOTAL AMOUNT SPENT BY AGE**

# %%
df.groupby('Age')['Purchase'].sum().plot(kind='bar',figsize=(12,6),rot=360,title='Total Purchase Distribution By Age')
# Out:
# <Axes: title={'center': 'Total Purchase Distribution By Age'}, xlabel='Age'>

# %% [markdown]
# **AVERAGE AMOUNT SPEND BY AGE**

# %%
df.groupby('Age')['Purchase'].mean().plot(kind='pie',autopct='%0.1f',title='Average Purchase Distribution By Age',figsize=(12,24))
# Out:
# <Axes: title={'center': 'Average Purchase Distribution By Age'}, ylabel='Purchase'>

# %% [markdown]
# **MARITIAL STATUS ANALYSIS**

# %%
df.groupby('Marital_Status').size().plot(kind='bar',figsize=(12,6),rot=360,title='Purchase Distribution By Maritial Status')
# Out:
# <Axes: title={'center': 'Purchase Distribution By Maritial Status'}, xlabel='Marital_Status'>

# %% [markdown]
# **MULTIVARIATE ANALYSIS**

# %%
sns.set(rc={'figure.figsize': (12,6)})
sns.countplot(x='Age',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.set(rc={'figure.figsize': (12,6)})
sns.countplot(x='Gender',hue='Age',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.set(rc={'figure.figsize': (6,6)})
sns.countplot(x='Gender',hue='Marital_Status',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.set(rc={'figure.figsize': (6,6)})
sns.countplot(x='Marital_Status',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
sns.countplot(x=df['City_Category'])
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.groupby('City_Category').size().plot(kind='pie',autopct='%0.1f')
# Out:
# <Axes: >

# %%
sns.set(rc={'figure.figsize': (6,6)})
sns.countplot(x='City_Category',hue='Age',data=df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.set(rc={'figure.figsize': (6,6)})
sns.countplot(x='City_Category',hue='Occupation',data=df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.set(rc={'figure.figsize': (6,6)})
sns.countplot(x='City_Category',hue='Gender',data=df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.groupby('City_Category')['Purchase'].sum().plot(kind='pie',autopct='%0.1f')
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby('City_Category')['Purchase'].sum().plot(kind='bar',figsize=(6,6),rot=360)
# Out:
# <Axes: xlabel='City_Category'>

# %%
df.groupby('City_Category')['Purchase'].mean().plot(kind='pie',autopct='%0.1f')
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby('City_Category')['Purchase'].mean().plot(kind='bar',figsize=(6,6),rot=360)
# Out:
# <Axes: xlabel='City_Category'>

# %% [markdown]
# **OCCUPATION AND STAY IN CURRENT CITY YEARS**

# %%
sns.countplot(x=df['Stay_In_Current_City_Years'])
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x=df['Stay_In_Current_City_Years'],hue=df['Gender'])
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x=df['Stay_In_Current_City_Years'],hue=df['Marital_Status'])
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x=df['Stay_In_Current_City_Years'],hue=df['City_Category'])
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
df.groupby('Stay_In_Current_City_Years').size().plot(kind='pie',autopct='%0.1f')
# Out:
# <Axes: >

# %%
df.groupby('Stay_In_Current_City_Years')['Purchase'].sum().plot(kind='pie',autopct='%0.1f')
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby('Stay_In_Current_City_Years')['Purchase'].mean().plot(kind='pie',autopct='%0.1f')
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby('Stay_In_Current_City_Years')['Purchase'].sum().plot(kind='bar',rot=360)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years'>

# %%
df.groupby('Occupation').size().sort_values().plot(kind='bar',rot=360)
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Occupation')['Purchase'].sum().sort_values().plot(kind='bar',rot=360)
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Occupation')['Purchase'].mean().sort_values().plot(kind='bar',rot=360)
# Out:
# <Axes: xlabel='Occupation'>

# %%
sns.countplot(x=df['Occupation'],hue=df['Marital_Status'])
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby('Occupation')['Purchase'].nunique().sort_values().plot(kind='bar',rot=360)
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Product_Category_1').size().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby('Product_Category_1')['Purchase'].sum().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby('Product_Category_1')['Purchase'].mean().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby('Product_ID')['Purchase'].sum().nlargest(10).sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %%
df.groupby('Product_ID')['Purchase'].mean().nlargest(10).sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %%
sns.countplot(x=df['Product_Category_1'],hue=df['Marital_Status'])
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
sns.countplot(x=df['Product_Category_1'],hue=df['Gender'])
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %% [markdown]
# **AGE AND MARITAL STATUS**

# %%
l=[]
for i in range(len(df)):
  l.append(df['Gender'][i]+'__'+str(df['Marital_Status'][i]))
df['MaritalGender']=l

# %%
sns.countplot(x=df['MaritalGender'])
# Out:
# <Axes: xlabel='MaritalGender', ylabel='count'>

# %%
sns.countplot(x=df['Age'],hue=df['MaritalGender'])
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x=df['Product_Category_1'],hue=df['MaritalGender'])
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
sns.countplot(x=df['Stay_In_Current_City_Years'],hue=df['MaritalGender'])
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x=df['City_Category'],hue=df['MaritalGender'])
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>
